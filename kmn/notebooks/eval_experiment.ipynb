# %%
import os
import matplotlib as mpl
if 'DISPLAY' not in os.environ: 
    mpl.use('Pdf')
import matplotlib.pyplot as plt
from kmn.dataset_generator import DatasetGenerator
from matplotlib.backends.backend_pdf import PdfPages
from kmn.experiment_evaluation import evaluate_experiment
mpl.rcParams['figure.facecolor'] = 'w'
mpl.rcParams['figure.figsize'] = [14.0, 6.0]
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
scene = "box"
runs = [
    "basic_vgpu2_1208_1626",
    "multi_keple_1208_1642",
    "partial_keple_1208_1642",
    ]

evaluate_experiment(runs, scene)
# Out:
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | Name                           | Train   | Test    | Train   | Test    | Train   | Test    |
# |                                | mae     | mae     | mae     | mae     | mspe    | mspe    |
# |                                | (trans) | (trans) | (conf)  | (conf)  |         |         |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | basic_vgpu2_1208_1626          | 0.00194 | 0.00313 | 0       | 0       | 0.00121 | 0.00122 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_keple_1208_1642          | 0.00032 | 0.00044 | 0       | 0       | 0.00033 | 0.00032 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | partial_keple_1208_1642        | 0.00183 | 0.00268 | 0       | 0       | 0.00119 | 0.00104 |
# ...

# %%
scene = "box_xy"
runs = [
    "basic_vgpu1_1215_1911",
    "multi_vgpu1_1225_1550"
    ]

evaluate_experiment(runs, scene)
# Out:
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | Name                           | Train   | Test    | Train   | Test    | Train   | Test    |
# |                                | mae     | mae     | mae     | mae     | mspe    | mspe    |
# |                                | (trans) | (trans) | (conf)  | (conf)  |         |         |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | basic_vgpu1_1215_1911          | 0.00090 | 0.00107 | 0       | 0       | 0.00143 | 0.00142 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_vgpu1_1225_1550          | 0.00068 | 0.00071 | 0       | 0       | 0.00136 | 0.00136 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+

# %%
scene = "box_trans"
runs = [
    "basic_keple_1208_2122",
    "multi_keple_1208_2123",
    "partial_vgpu2_1208_2124",
    ]

evaluate_experiment(runs, scene)
# Out:
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | Name                           | Train   | Test    | Train   | Test    | Train   | Test    |
# |                                | mae     | mae     | mae     | mae     | mspe    | mspe    |
# |                                | (trans) | (trans) | (conf)  | (conf)  |         |         |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | basic_keple_1208_2122          | 0.00785 | 0.01629 | 0       | 0       | 0.00734 | 0.00734 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_keple_1208_2123          | 0.00082 | 0.00105 | 0       | 0       | 0.00251 | 0.00314 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | partial_vgpu2_1208_2124        | 0.00867 | 0.01785 | 0       | 0       | 0.00967 | 0.00964 |
# ...

# %%
scene = "box_complex"
runs = [
    "basic_vgpu1_1226_1729",
    "multi_snuff_1208_2059"
]

evaluate_experiment(runs, scene)
# Out:
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | Name                           | Train   | Test    | Train   | Test    | Train   | Test    |
# |                                | mae     | mae     | mae     | mae     | mspe    | mspe    |
# |                                | (trans) | (trans) | (conf)  | (conf)  |         |         |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | basic_vgpu1_1226_1729          | 0.01460 | 0.02534 | 0       | 0       | 0.04242 | 0.04295 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_snuff_1208_2059          | 0.00521 | 0.00778 | 0       | 0       | 0.03099 | 0.04679 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+

# %%
scene = "door"
runs = [
    "basic_keple_1214_1837",
    "multi_large_vgpu1_0102_1507",
    "multi_vgpu2_1211_1207",
    "separate_keple_1225_1541"
    ]

evaluate_experiment(runs, scene)
# Out:
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | Name                           | Train   | Test    | Train   | Test    | Train   | Test    |
# |                                | mae     | mae     | mae     | mae     | mspe    | mspe    |
# |                                | (trans) | (trans) | (conf)  | (conf)  |         |         |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | basic_keple_1214_1837          | 0.00619 | 0.01043 | 0.01304 | 0.01898 | 0.05253 | 0.05307 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_large_vgpu1_0102_1507    | 0.00587 | 0.00621 | 0.01332 | 0.01353 | 0.07085 | 0.07141 |
# +--------------------------------+---------+---------+---------+---------+---------+---------+
# | multi_vgpu2_1211_1207          | 0.00577 | 0.00634 | 0.01223 | 0.01249 | 0.06774 | 0.07029 |
# ...
